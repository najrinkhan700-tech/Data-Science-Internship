# %% [markdown]
# <!-- Data Filtering in Pandas -->

# %% [markdown]
# # Data Filtering in Pandas

# %%
# Objective

# Create a filtered version of the dataset by:

# Filtering rows
# Selecting columns
# Sorting data

# %%
# 1. Import Pandas
import pandas as pd

# %%
# 2. Read CSV File
df = pd.read_csv("fashion_sales_1000_rows.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 2. Read CSV File
# ----> 2 df = pd.read_csv("fashion_sales_1000_rows.csv")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
# 3. Display Dataset
df.head()

# %%
# 4. Select Columns
df["Product Name"]

# %%
df[["Product Name", "Total Sales", "City"]]
# Out:
#      Product Name  Total Sales         City
# 0      Slim Jeans      4966.00      Chennai
# 1    Casual Shirt      9719.50         Pune
# 2        Sneakers      2407.30        Delhi
# 3     Cargo Jeans       655.50  Bhubaneswar
# 4      Travel Bag      4029.00    Hyderabad
# ..            ...          ...          ...
# 995       Sandals      2056.80       Jaipur
# 996  Baseball Cap     13920.00       Indore
# 997  Baseball Cap     15500.00  Bhubaneswar
# 998  Formal Shoes       929.90       Jaipur
# 999  Formal Shirt     15584.75       Indore
#
# [1000 rows x 3 columns]

# %%
# 5. Filter Rows
df[df["Total Sales"] > 10000]
# Out:
#      Order ID  Order Date Month  Customer Name  Gender Region         City  \
# 6    ORD10007  2025-12-02   Dec     Customer_7     Men   East  Bhubaneswar
# 7    ORD10008  2025-03-12   Mar     Customer_8     Men   East  Bhubaneswar
# 17   ORD10018  2025-08-05   Aug    Customer_18     Men   West    Ahmedabad
# 19   ORD10020  2025-08-03   Aug    Customer_20  Unisex  North        Delhi
# 30   ORD10031  2025-06-03   Jun    Customer_31  Unisex   East      Kolkata
# ..        ...         ...   ...            ...     ...    ...          ...
# 985  ORD10986  2025-04-12   Apr   Customer_986   Women  South        Kochi
# 987  ORD10988  2025-04-07   Apr   Customer_988   Women   East     Guwahati
# 996  ORD10997  2025-03-20   Mar   Customer_997     Men   West       Indore
# 997  ORD10998  2025-03-15   Mar   Customer_998   Women   East  Bhubaneswar
# 999  ORD11000  2025-05-25   May  Customer_1000  Unisex   West       Indore
#
# ...

# %%
# Only Delhi records
df[df["City"] == "Delhi"]
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region   City Category  \
# 2    ORD10003  2025-07-14   Jul    Customer_3     Men  North  Delhi    Shoes
# 16   ORD10017  2025-02-17   Feb   Customer_17   Women  North  Delhi     Caps
# 19   ORD10020  2025-08-03   Aug   Customer_20  Unisex  North  Delhi  Jackets
# 24   ORD10025  2025-12-20   Dec   Customer_25  Unisex  North  Delhi  Dresses
# 33   ORD10034  2025-05-06   May   Customer_34  Unisex  North  Delhi  Jackets
# ..        ...         ...   ...           ...     ...    ...    ...      ...
# 865  ORD10866  2025-07-09   Jul  Customer_866     Men  North  Delhi    Shoes
# 941  ORD10942  2025-11-02   Nov  Customer_942   Women  North  Delhi    Shoes
# 955  ORD10956  2025-07-30   Jul  Customer_956   Women  North  Delhi     Bags
# 957  ORD10958  2025-09-24   Sep  Customer_958   Women  North  Delhi    Shoes
# 976  ORD10977  2025-11-11   Nov  Customer_977     Men  North  Delhi   Shirts
#
# ...

# %%
# Shoes category
df[df["Category"] == "Shoes"]
# Out:
#      Order ID  Order Date Month Customer Name  Gender

# Out:
#      Order ID  Order Date Month Customer Name  Gender Region         City  \
# 0    ORD10001  2025-03-13   Mar    Customer_1     Men  South      Chennai
# 3    ORD10004  2025-12-27   Dec    Customer_4     Men   East  Bhubaneswar
# 8    ORD10009  2025-10-11   Oct    Customer_9  Unisex   West    Ahmedabad
# 11   ORD10012  2025-03-07   Mar   Customer_12   Women  North       Jaipur
# 13   ORD10014  2025-01-17   Jan   Customer_14   Women  South    Bangalore
# ..        ...         ...   ...           ...     ...    ...          ...
# 968  ORD10969  2025-05-15   May  Customer_969   Women  North   Chandigarh
# 969  ORD10970  2025-05-06   May  Customer_970   Women   West       Mumbai
# 978  ORD10979  2025-05-10   May  Customer_979     Men  South        Kochi
# 982  ORD10983  2025-12-16   Dec  Customer_983     Men  North      Lucknow
# 984  ORD10985  2025-09-24   Sep  Customer_985  Unisex   West       Mumbai
#
#     Category   Product Name        Brand       Size  Color  Units Sold  \
# ...

# %%
# 7. isin()
df[df["City"].isin(["Delhi", "Mumbai"])]
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region    City Category  \
# 2    ORD10003  2025-07-14   Jul    Customer_3     Men  North   Delhi    Shoes
# 16   ORD10017  2025-02-17   Feb   Customer_17   Women  North   Delhi     Caps
# 19   ORD10020  2025-08-03   Aug   Customer_20  Unisex  North   Delhi  Jackets
# 24   ORD10025  2025-12-20   Dec   Customer_25  Unisex  North   Delhi  Dresses
# 33   ORD10034  2025-05-06   May   Customer_34  Unisex  North   Delhi  Jackets
# ..        ...         ...   ...           ...     ...    ...     ...      ...
# 955  ORD10956  2025-07-30   Jul  Customer_956   Women  North   Delhi     Bags
# 957  ORD10958  2025-09-24   Sep  Customer_958   Women  North   Delhi    Shoes
# 969  ORD10970  2025-05-06   May  Customer_970   Women   West  Mumbai    Jeans
# 976  ORD10977  2025-11-11   Nov  Customer_977     Men  North   Delhi   Shirts
# 984  ORD10985  2025-09-24   Sep  Customer_985  Unisex   West  Mumbai   Shirts
#
# ...

# %%
# 8. Between()
df[df["Total Sales"].between(5000,15000)]
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region         City  \
# 1    ORD10002  2025-08-18   Aug    Customer_2  Unisex   West         Pune
# 5    ORD10006  2025-11-24   Nov    Customer_6     Men   West    Ahmedabad
# 6    ORD10007  2025-12-02   Dec    Customer_7     Men   East  Bhubaneswar
# 9    ORD10010  2025-09-14   Sep   Customer_10  Unisex  North      Lucknow
# 11   ORD10012  2025-03-07   Mar   Customer_12   Women  North       Jaipur
# ..        ...         ...   ...           ...     ...    ...          ...
# 987  ORD10988  2025-04-07   Apr  Customer_988   Women   East     Guwahati
# 990  ORD10991  2025-11-15   Nov  Customer_991   Women  South      Chennai
# 991  ORD10992  2025-04-08   Apr  Customer_992   Women   West    Ahmedabad
# 993  ORD10994  2025-03-03   Mar  Customer_994     Men   East      Kolkata
# 996  ORD10997  2025-03-20   Mar  Customer_997     Men   West       Indore
#
#     Category  Product Name           Brand       Size  Color  Units Sold  \
# ...

# %%
# 9. String Filtering
# Starts with A
df[df["Customer Name"].str.startswith("A")]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Month, Customer Name, Gender, Region, City, Category, Product Name, Brand, Size, Color, Units Sold, Unit Price, Discount %, Total Sales, Profit, Payment Mode, Delivery Status]
# Index: []

# %%
# Contains "phone"
df[df["Product Name"].str.contains("phone", case=False)]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Month, Customer Name, Gender, Region, City, Category, Product Name, Brand, Size, Color, Units Sold, Unit Price, Discount %, Total Sales, Profit, Payment Mode, Delivery Status]
# Index: []

# %%
# 10. Sort Values
# Sales ascending
df.sort_values("Total Sales")
# Out:
#      Order ID  Order Date Month Customer Name Gender Region         City  \
# 695  ORD10696  2025-10-01   Oct  Customer_696  Women  South      Chennai
# 273  ORD10274  2025-02-18   Feb  Customer_274    Men   West       Mumbai
# 417  ORD10418  2025-06-26   Jun  Customer_418    Men   East     Guwahati
# 23   ORD10024  2025-05-22   May   Customer_24  Women  North   Chandigarh
# 255  ORD10256  2025-09-20   Sep  Customer_256    Men   East     Guwahati
# ..        ...         ...   ...           ...    ...    ...          ...
# 7    ORD10008  2025-03-12   Mar    Customer_8    Men   East  Bhubaneswar
# 161  ORD10162  2025-08-02   Aug  Customer_162    Men  North   Chandigarh
# 370  ORD10371  2025-11-01   Nov  Customer_371  Women   West       Indore
# 308  ORD10309  2025-08-26   Aug  Customer_309    Men   East  Bhubaneswar
# 444  ORD10445  2025-12-17   Dec  Customer_445    Men   East      Kolkata
#
#     Category   Product Name           Brand       Size  Color  Units Sold  \
# ...

# %%
# Sales descending
df.sort_values("Total Sales", ascending=False)
# Out:
#      Order ID  Order Date Month Customer Name Gender Region         City  \
# 444  ORD10445  2025-12-17   Dec  Customer_445    Men   East      Kolkata
# 308  ORD10309  2025-08-26   Aug  Customer_309    Men   East  Bhubaneswar
# 370  ORD10371  2025-11-01   Nov  Customer_371  Women   West       Indore
# 161  ORD10162  2025-08-02   Aug  Customer_162    Men  North   Chandigarh
# 7    ORD10008  2025-03-12   Mar    Customer_8    Men   East  Bhubaneswar
# ..        ...         ...   ...           ...    ...    ...          ...
# 255  ORD10256  2025-09-20   Sep  Customer_256    Men   East     Guwahati
# 23   ORD10024  2025-05-22   May   Customer_24  Women  North   Chandigarh
# 417  ORD10418  2025-06-26   Jun  Customer_418    Men   East     Guwahati
# 273  ORD10274  2025-02-18   Feb  Customer_274    Men   West       Mumbai
# 695  ORD10696  2025-10-01   Oct  Customer_696  Women  South      Chennai
#
#     Category   Product Name           Brand       Size  Color  Units Sold  \
# ...

# %%
# Multiple columns
df.sort_values(["City","Total Sales"], ascending=[True,False])
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region       City  \
# 17   ORD10018  2025-08-05   Aug   Customer_18     Men   West  Ahmedabad
# 599  ORD10600  2025-09-13   Sep  Customer_600  Unisex   West  Ahmedabad
# 57   ORD10058  2025-09-14   Sep   Customer_58   Women   West  Ahmedabad
# 141  ORD10142  2025-03-30   Mar  Customer_142  Unisex   West  Ahmedabad
# 495  ORD10496  2025-07-12   Jul  Customer_496  Unisex   West  Ahmedabad
# ..        ...         ...   ...           ...     ...    ...        ...
# 843  ORD10844  2025-10-11   Oct  Customer_844     Men   West       Pune
# 139  ORD10140  2025-12-15   Dec  Customer_140     Men   West       Pune
# 502  ORD10503  2025-11-16   Nov  Customer_503  Unisex   West       Pune
# 554  ORD10555  2025-06-04   Jun  Customer_555  Unisex   West       Pune
# 156  ORD10157  2025-04-25   Apr  Customer_157  Unisex   West       Pune
#
#     Category   Product Name           Brand       Size  Color  Units Sold  \
# ...

# %%
# Largest Sales
# Top 10 sales
df.nlargest(10,"Total Sales")
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region         City  \
# 444  ORD10445  2025-12-17   Dec  Customer_445     Men   East      Kolkata
# 308  ORD10309  2025-08-26   Aug  Customer_309     Men   East  Bhubaneswar
# 370  ORD10371  2025-11-01   Nov  Customer_371   Women   West       Indore
# 161  ORD10162  2025-08-02   Aug  Customer_162     Men  North   Chandigarh
# 7    ORD10008  2025-03-12   Mar    Customer_8     Men   East  Bhubaneswar
# 609  ORD10610  2025-12-19   Dec  Customer_610   Women  South    Bangalore
# 771  ORD10772  2025-09-23   Sep  Customer_772  Unisex   East        Patna
# 847  ORD10848  2025-05-26   May  Customer_848  Unisex   East     Guwahati
# 19   ORD10020  2025-08-03   Aug   Customer_20  Unisex  North        Delhi
# 542  ORD10543  2025-09-20   Sep  Customer_543     Men   West       Indore
#
#     Category   Product Name           Brand       Size  Color  Units Sold  \
# 444  Watches   Sports Watch        Roadster  Free Size  White           5
# ...

# %%
# Lowest 10 sales
df.nsmallest(10,"Total Sales")
# Out:
#      Order ID  Order Date Month Customer Name  Gender Region         City  \
# 695  ORD10696  2025-10-01   Oct  Customer_696   Women  South      Chennai
# 273  ORD10274  2025-02-18   Feb  Customer_274     Men   West       Mumbai
# 417  ORD10418  2025-06-26   Jun  Customer_418     Men   East     Guwahati
# 23   ORD10024  2025-05-22   May   Customer_24   Women  North   Chandigarh
# 255  ORD10256  2025-09-20   Sep  Customer_256     Men   East     Guwahati
# 342  ORD10343  2025-10-08   Oct  Customer_343     Men  North   Chandigarh
# 735  ORD10736  2025-02-23   Feb  Customer_736   Women  North        Delhi
# 393  ORD10394  2025-08-15   Aug  Customer_394  Unisex   West       Indore
# 157  ORD10158  2025-04-07   Apr  Customer_158     Men  South    Hyderabad
# 834  ORD10835  2025-10-13   Oct  Customer_835     Men   East  Bhubaneswar
#
#     Category   Product Name           Brand       Size  Color  Units Sold  \
# 695    Shoes   Formal Shoes            Nike          L   Blue           1
# ...

# %%
# Save Filtered Dataset
filtered = df[df["Total Sales"] > 10000]

filtered.to_csv("Filtered_Data.csv", index=False)
