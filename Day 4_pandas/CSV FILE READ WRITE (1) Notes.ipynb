# %%
# CSV DATA READ AND WRITE

# %%
#Method 1 Csv data read

# %%
import pandas as pd

# %%
df = pd.read_csv('fileofcsv.csv')   # Make sure 'filename.csv' is in the same folder
print(df)
# Out:
#           Names  Age       City Unnamed: 3 Product Order ID       Phone  \
# 0   Neha Singh    28     mumbai     Mumbai  Tablet   ORD003  9988776655
# 1    Priya Shah   23  Ahmedabad  Ahmedabad  Mobile   ORD009  9898989899
# 2   Karan Patel    0  Ahmedabad  Ahmedabad  Mobile   ORD008  9898989898
# 3     Raj Mehta   27       pune       Pune  Tablet   ORD006  9876543212
# 4  Rahul Sharma   25      Delhi      Delhi  Laptop   ORD001  9876543210
# 5    Vikas Jain   26      Pune       Pune   Laptop   ORD007  9812345678
# 6    Amit Kumar  150     mumbai     Mumbai  Laptop   ORD004  9123456789
# 7      Sita Roy   24       Pune       Pune  Mobile   ORD005           0
# 8     Anu Verma    0      Delhi      Delhi  Mobile   ORD002           0
# 9     Anu Verma   22      Delhi      Delhi  Mobile   ORD002           0
#
#     Sales Amount
# 0          25000
# 1          32000
# 2  not_available
# 3          27000
# 4          55000
# 5          50000
# 6          70000
# 7          20000
# ...

# %%
#Method 2: Create CSV using Pandas in Python

import pandas as pd

# Create a DataFrame
data = {
    'Name': ['aishwarya', 'harman', 'Kriti'],
    'Age': [14, 15, 14],
    'Marks': [85, 90, 88]
}

df = pd.DataFrame(data)
 
# Save to CSV file', index=False)   # index=False to avoid saving row numbers
#you can give the existing
df.to_csv('participants.csv')
         # csv file name or new csv file .If ypu are writing the existing fie name then existing data will be overriden by new data
