# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
data = {
    "Name" : ["Rahul","Neha","Rohit","Ashi"],
    "Age" :[22,21,23,24]
}

# %%
df = pd.DataFrame(data,"A B C D".split())

# %%
print(df)
# Out:
#     Name  Age
# A  Rahul   22
# B   Neha   21
# C  Rohit   23
# D   Ashi   24
