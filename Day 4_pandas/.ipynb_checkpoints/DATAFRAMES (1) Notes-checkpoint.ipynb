# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index.

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
# np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -0.728567 -0.875105  1.152605  1.137116
# B  1.012902 -0.545902 -0.972971  0.455320
# C  0.542612  0.732853  0.491945 -0.657054
# D -1.100653 -1.399394 -1.581268 -0.720183
# E  0.601392 -0.102232  0.313621 -1.219543

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
# SQL Syntax (NOT RECOMMENDED!)
.Wdf
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# Not inplace unless specified!
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['B','Y']
# Out:
# -0.84807698340363147

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# A -1.107699 -0.986391  0.483492  1.044794
# B  0.546165 -1.237887 -0.947141  0.684018
# C -0.077049 -0.051724 -0.838379 -2.131966
# D -0.136701  0.955704 -0.396120  1.256016
# E  0.176443 -0.105070 -1.488284  0.273486

# %%
df = pd.DataFrame(np.random.randn(5,4),index=list('ABCDE'),columns=list('WXYZ'))
print(df)
df > 0
# Out:
#           W         X         Y         Z
# A  0.031297  0.289200 -0.866946 -2.632379
# B  0.073018  1.075965 -0.445919 -0.738509
# C -0.903948  1.382867  1.447587  1.705895
# D -1.418520  0.748160  1.469832 -1.222215
# E  0.884279 -0.212057 -1.556660  0.215033
#        W      X      Y      Z
# A   True   True  False  False
# B   True   True  False  False
# C  False   True   True   True
# D  False   True   True  False
# E   True  False  False   True

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) 
print(df)
df[df>0]
# Out:
#           W         X         Y         Z
# A -1.567576  1.554394  0.837414  0.465080
# B -1.168549  0.345573 -1.200207 -1.511980
# C -1.428470 -0.336880 -0.577003 -1.399343
# D  0.532560 -0.009731 -0.433333 -0.377228
# E  0.361631  0.256740 -0.045513 -0.805066
#           W         X         Y        Z
# A       NaN  1.554394  0.837414  0.46508
# B       NaN  0.345573       NaN      NaN
# C       NaN       NaN       NaN      NaN
# D  0.532560       NaN       NaN      NaN
# E  0.361631  0.256740       NaN      NaN

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) 
print(df)

df[df['W']>0]
# Out:
#           W         X         Y         Z
# A -0.604810  1.547174 -1.944020  0.251094
# B  1.487218 -0.209059 -0.265830 -0.447282
# C  0.308820 -0.195763  0.700193  1.598290
# D -1.178769 -0.343392  0.443627  0.097398
# E -0.020236  1.042003 -0.588219 -2.100898
#           W         X         Y         Z
# B  1.487218 -0.209059 -0.265830 -0.447282
# C  0.308820 -0.195763  0.700193  1.598290

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) 
df[df['W']>0]['Y']
# Out:
# A   -1.481126
# B    0.627123
# Name: Y, dtype: float64

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) 
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# B -0.614338  0.505969

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
print(df)
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# A  0.272449  0.667546  0.554161 -1.061096
# B  0.428197 -0.377538  1.351591  0.832571
# C -1.641635 -1.678208 -0.798341 -0.387239
# D -0.327022  0.532658  0.688979 -0.171354
# E  0.822911  0.435446  0.704263 -0.082682
#           W         X         Y         Z
# B  0.428197 -0.377538  1.351591  0.832571

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.997799 -0.167853 -0.466384  0.806693
# B -1.681992  0.337174  1.853489  0.252892
# C -0.564839  1.544156 -0.227732 -1.425625
# D -1.037810  0.241291  2.837304 -0.656334
# E  1.562381  1.286141 -0.391676 -0.366903

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ## Multi-Index and Index Hierarchy
#
# Let us go over how to work with Multi-Index, first we'll create a quick example of what a Multi-Indexed DataFrame would look like:

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1  0.377749  0.250345
#    2  0.226194 -0.595992
#    3 -0.188389 -1.369247
# G2 1  0.588699  2.380206
#    2  0.789132  0.835558
#    3 -0.089876  1.273670

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.377749  0.250345
# 2  0.226194 -0.595992
# 3 -0.188389 -1.369247

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.377749
# B    0.250345
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    0.377749  0.250345
#       2    0.226194 -0.595992
#       3   -0.188389 -1.369247
# G2    1    0.588699  2.380206
#       2    0.789132  0.835558
#       3   -0.089876  1.273670

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.377749  0.250345
# 2    0.226194 -0.595992
# 3   -0.188389 -1.369247

# %%
df.xs(('G1',1))
# Out:
# A    0.377749
# B    0.250345
# Name: (G1, 1), dtype: float64

# %%
df.xs((1,level ='Num'))
# Out:
#   Cell In[26], line 1
#     df.xs((1,level ='Num'))
#              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# # Great Job!
