# %%
# READING WRITHING HTML FILE 
# !pip install lxml html5lib beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#READING HTML FILE (EXISTING)
import pandas as pd

tables = pd.read_html('table.html')

# %%
print(tables)
# Out:
# [     Name  Age  Marks
# 0   Swati   21     85
# 1    Amit   22     90
# 2  Simran   20     88]

# %%
# Access the Desired Table

df = tables[0]   # If there's only one table
print(df)
# Out:
#      Name  Age  Marks
# 0   Swati   21     85
# 1    Amit   22     90
# 2  Simran   20     88

# %%
#WRITING HTML FILE

# %%
import pandas as pd

# %%
data = {
    'Name': ['Swati', 'Amit', 'Simran'],
    'Age': [21, 22, 20],
    'Marks': [85, 90, 88]
}

df = pd.DataFrame(data)

# %%
df.to_html('students.html', index=False)

# %%
#READING WEBSITE HTML FILE

# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"
tables = pd.read_html(url)

# Show how many tables were found
# print(f"Total tables found: {len(tables)}")
print(tables)

# Display the first table

df = tables[0]
print(df)

print(df.head(3))
# Out:
#                                                    0
# 0  Largest economies in the world by GDP (nominal...
#                                                    0
# 0  Largest economies in the world by GDP (nominal...

# %%
#How to Choose the Right Table
#If there are multiple tables, you can check them one by one:


for i, table in enumerate(tables):
    print(f"\nTable {i}")
    print(table.head())
# Out:
# Table 0
#                                                    0
# 0  Largest economies in the world by GDP (nominal...
#
# Table 1
#                                                    0  \
# 0  > $20 trillion $10–20 trillion $5–10 trillion ...
#
#                                                    1  \
# 0  $750 billion – $1 trillion $500–750 billion $2...
#
#                                                    2
# 0  $50–100 billion $25–50 billion $5–25 billion <...
#
# Table 2
#   Country/Territory IMF[1][12]            World Bank[13]             \
#   Country/Territory   Forecast       Year       Estimate       Year
# 0             World  113795678       2025      111326370       2024
# 1     United States   30507217       2025       29184890       2024
# 2             China   19231705  [n 1]2025       18743803  [n 3]2024
# 3           Germany    4744804       2025        4659929       2024
# 4             India    4187017       2025        3912686       2024
#
# ...

# %%
# Thing to Know	Explanation
# Website must have <table> tag -Otherwise read_html() won't work

# Works only for public pages-No login/authentication supported
