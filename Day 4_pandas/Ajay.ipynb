# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
# series are one dimension array
i = ["A","B","C","D","E"]
s = pd.Series([10,20,30,40,50],index = i)
print(s)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
data = {
    "Product" : ["Laptop", "Smartphone", "Tablet"],
    "Price" : [40000, 34000, 50000],
    "Quantity" : [2,1,3]
}
df = pd.DataFrame(data , index = ["a","b","c"])
df
# Out:
#       Product  Price  Quantity
# a      Laptop  40000         2
# b  Smartphone  34000         1
# c      Tablet  50000         3

# %%
df.loc['a',"Price"]
# Out:
# np.int64(40000)

# %%
df.iloc[0, 1]
# Out:
# np.int64(40000)

# %%
# read csv data
df = pd.read_csv("Pn_data.csv")

# %%
# read excel data
df = pd.read_excel("Sales_Dashboard_Data_1000_Rows_20_Columns.xlsx")

# %%
#  save file in csv
# df.to_csv("Sales.csv",index = False)

# %%
df.head()
# Out:
#    OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City State  \
# 0    10001  2025-12-27        2271  Customer_2271  Female   52  Gwalior    MP
# 1    10002  2025-08-12        2194  Customer_2194    Male   53   Indore    MP
# 2    10003  2025-05-08        2135  Customer_2135    Male   27  Lucknow    UP
# 3    10004  2025-07-18        2137  Customer_2137    Male   27   Indore    MP
# 4    10005  2025-04-29        2071  Customer_2071    Male   31  Gwalior    MP
#
#   Region ProductID     Category Product  Quantity  UnitPrice  DiscountPct  \
# 0  North      P662     Clothing   Jeans         1      40160            5
# 1   West      P566    Furniture   Table         1      29341            5
# 2  North      P966  Electronics  Laptop         3      38968           15
# 3   West      P754    Furniture   Table        10      29099           10
# 4  North      P467     Clothing   Jeans         3      27041           15
#
# ...

# %%
df.tail(1)
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName Gender  Age    City State  \
# 999    11000  2025-01-02        2058  Customer_2058   Male   45  Indore    MP
#
#     Region ProductID     Category Product  Quantity  UnitPrice  DiscountPct  \
# 999   West      P478  Electronics  Laptop         5      17572           20
#
#        Sales     Cost  Profit PaymentMode SalesPerson
# 999  70288.0  61502.0  8786.0         UPI        Neha

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       1000 non-null   int64
#  1   OrderDate     1000 non-null   str
#  2   CustomerID    1000 non-null   int64
#  3   CustomerName  1000 non-null   str
#  4   Gender        1000 non-null   str
#  5   Age           1000 non-null   int64
#  6   City          1000 non-null   str
#  7   State         1000 non-null   str
#  8   Region        1000 non-null   str
#  9   ProductID     1000 non-null   str
#  10  Category      1000 non-null   str
#  11  Product       1000 non-null   str
#  12  Quantity      1000 non-null   int64
#  13  UnitPrice     1000 non-null   int64
#  14  DiscountPct   1000 non-null   int64
#  15  Sales         1000 non-null   float64
#  16  Cost          1000 non-null   float64
#  17  Profit        1000 non-null   float64
#  18  PaymentMode   1000 non-null   str
# ...

# %%
df.describe()
# Out:
#             OrderID   CustomerID          Age     Quantity     UnitPrice  \
# count   1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean   10500.500000  2153.785000    39.865000     5.497000  24550.340000
# std      288.819436    84.431436    12.025864     2.851337  14049.555203
# min    10001.000000  2001.000000    18.000000     1.000000    204.000000
# 25%    10250.750000  2080.000000    30.000000     3.000000  12774.250000
# 50%    10500.500000  2153.000000    40.000000     6.000000  24060.500000
# 75%    10750.250000  2226.000000    50.000000     8.000000  36617.000000
# max    11000.000000  2300.000000    60.000000    10.000000  49954.000000
#
#        DiscountPct         Sales          Cost         Profit
# count  1000.000000    1000.00000    1000.00000    1000.000000
# mean      9.975000  122208.04210   94943.54450   27264.497600
# std       7.157206  102977.72842   79273.64029   26203.048859
# min       0.000000     603.90000     469.70000     118.000000
# ...

# %%
df.shape
# Out:
# (1000, 20)

# %%
df.head()
# Out:
#    OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City State  \
# 0    10001  2025-12-27        2271  Customer_2271  Female   52  Gwalior    MP
# 1    10002  2025-08-12        2194  Customer_2194    Male   53   Indore    MP
# 2    10003  2025-05-08        2135  Customer_2135    Male   27  Lucknow    UP
# 3    10004  2025-07-18        2137  Customer_2137    Male   27   Indore    MP
# 4    10005  2025-04-29        2071  Customer_2071    Male   31  Gwalior    MP
#
#   Region ProductID     Category Product  Quantity  UnitPrice  DiscountPct  \
# 0  North      P662     Clothing   Jeans         1      40160            5
# 1   West      P566    Furniture   Table         1      29341            5
# 2  North      P966  Electronics  Laptop         3      38968           15
# 3   West      P754    Furniture   Table        10      29099           10
# 4  North      P467     Clothing   Jeans         3      27041           15
#
# ...

# %%
# df.loc[0,"City"]

# %%
# df.iloc[0,7]

# %%
df["Age"] # clomn selecttion
# Out:
# 0      52
# 1      53
# 2      27
# 3      27
# 4      31
#        ..
# 995    48
# 996    40
# 997    32
# 998    39
# 999    45
# Name: Age, Length: 1000, dtype: int64

# %%
df[["Age","City","Product"]]
# Out:
#      Age     City   Product
# 0     52  Gwalior     Jeans
# 1     53   Indore     Table
# 2     27  Lucknow    Laptop
# 3     27   Indore     Table
# 4     31  Gwalior     Jeans
# ..   ...      ...       ...
# 995   48    Delhi    Jacket
# 996   40   Mumbai  Keyboard
# 997   32   Indore    Laptop
# 998   39   Mumbai     Sugar
# 999   45   Indore    Laptop
#
# [1000 rows x 3 columns]

# %%
df[df["Sales"] > 290000] # filtering data
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City  \
# 26     10027  2025-06-11        2108  Customer_2108    Male   56   Indore
# 63     10064  2025-07-16        2093  Customer_2093  Female   43  Lucknow
# 73     10074  2025-10-13        2197  Customer_2197    Male   54  Gwalior
# 74     10075  2025-09-14        2158  Customer_2158  Female   58  Gwalior
# 77     10078  2025-01-12        2111  Customer_2111  Female   27    Delhi
# ..       ...         ...         ...            ...     ...  ...      ...
# 931    10932  2025-06-09        2292  Customer_2292    Male   26  Gwalior
# 940    10941  2025-10-06        2019  Customer_2019    Male   38    Delhi
# 950    10951  2025-04-27        2104  Customer_2104    Male   58   Indore
# 959    10960  2025-12-18        2148  Customer_2148  Female   21   Jaipur
# 998    10999  2025-02-09        2220  Customer_2220  Female   39   Mumbai
#
#      State Region ProductID     Category Product  Quantity  UnitPrice  \
# ...

# %%
df[df["City"] == "Indore"]
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age    City  \
# 1      10002  2025-08-12        2194  Customer_2194    Male   53  Indore
# 3      10004  2025-07-18        2137  Customer_2137    Male   27  Indore
# 5      10006  2025-02-24        2136  Customer_2136  Female   51  Indore
# 9      10010  2025-05-27        2151  Customer_2151    Male   44  Indore
# 20     10021  2025-09-23        2242  Customer_2242  Female   41  Indore
# ..       ...         ...         ...            ...     ...  ...     ...
# 988    10989  2025-11-03        2149  Customer_2149    Male   49  Indore
# 991    10992  2025-09-07        2042  Customer_2042  Female   52  Indore
# 993    10994  2025-11-07        2270  Customer_2270    Male   36  Indore
# 997    10998  2025-09-12        2217  Customer_2217    Male   32  Indore
# 999    11000  2025-01-02        2058  Customer_2058    Male   45  Indore
#
#     State Region ProductID     Category   Product  Quantity  UnitPrice  \
# ...

# %%
df.sort_values("Sales", inplace = False)
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City  \
# 347    10348  2025-02-12        2096  Customer_2096  Female   58   Jaipur
# 286    10287  2025-06-29        2002  Customer_2002    Male   22   Mumbai
# 126    10127  2025-04-12        2029  Customer_2029    Male   26    Delhi
# 455    10456  2025-01-11        2271  Customer_2271  Female   23  Lucknow
# 653    10654  2025-03-06        2053  Customer_2053  Female   21   Mumbai
# ..       ...         ...         ...            ...     ...  ...      ...
# 758    10759  2025-05-17        2107  Customer_2107  Female   18   Mumbai
# 340    10341  2025-12-12        2190  Customer_2190    Male   34   Jaipur
# 282    10283  2025-04-03        2203  Customer_2203  Female   24    Delhi
# 745    10746  2025-09-16        2152  Customer_2152  Female   58   Indore
# 665    10666  2025-10-02        2257  Customer_2257  Female   56    Delhi
#
#      State Region ProductID     Category   Product  Quantity  UnitPrice  \
# ...

# %%
df.head(3)
# Out:
#    OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City State  \
# 0    10001  2025-12-27        2271  Customer_2271  Female   52  Gwalior    MP
# 1    10002  2025-08-12        2194  Customer_2194    Male   53   Indore    MP
# 2    10003  2025-05-08        2135  Customer_2135    Male   27  Lucknow    UP
#
#   Region ProductID     Category Product  Quantity  UnitPrice  DiscountPct  \
# 0  North      P662     Clothing   Jeans         1      40160            5
# 1   West      P566    Furniture   Table         1      29341            5
# 2  North      P966  Electronics  Laptop         3      38968           15
#
#       Sales     Cost    Profit PaymentMode SalesPerson
# 0  38152.00  28112.0  10040.00        Card       Rahul
# 1  27873.95  20538.7   7335.25        Cash        Neha
# 2  99368.40  81832.8  17535.60         UPI        Amit

# %%
df.tail()
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age    City  \
# 995    10996  2025-08-21        2062  Customer_2062  Female   48   Delhi
# 996    10997  2025-05-21        2034  Customer_2034  Female   40  Mumbai
# 997    10998  2025-09-12        2217  Customer_2217    Male   32  Indore
# 998    10999  2025-02-09        2220  Customer_2220  Female   39  Mumbai
# 999    11000  2025-01-02        2058  Customer_2058    Male   45  Indore
#
#      State Region ProductID     Category   Product  Quantity  UnitPrice  \
# 995  Delhi  North      P746     Clothing    Jacket         6       2759
# 996     MH   West      P956  Electronics  Keyboard         7      39196
# 997     MP   West      P223  Electronics    Laptop         2      39774
# 998     MH   West      P602      Grocery     Sugar         8      48968
# 999     MP   West      P478  Electronics    Laptop         5      17572
#
#      DiscountPct     Sales      Cost    Profit  PaymentMode SalesPerson
# ...

# %%
df.sort_values(by = "Quantity")
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City  \
# 0      10001  2025-12-27        2271  Customer_2271  Female   52  Gwalior
# 1      10002  2025-08-12        2194  Customer_2194    Male   53   Indore
# 969    10970  2025-12-31        2143  Customer_2143    Male   37  Gwalior
# 970    10971  2025-06-04        2075  Customer_2075  Female   46   Indore
# 972    10973  2025-05-20        2190  Customer_2190  Female   24    Delhi
# ..       ...         ...         ...            ...     ...  ...      ...
# 966    10967  2025-11-11        2097  Customer_2097  Female   49    Delhi
# 74     10075  2025-09-14        2158  Customer_2158  Female   58  Gwalior
# 75     10076  2025-04-10        2020  Customer_2020  Female   59   Indore
# 564    10565  2025-07-20        2284  Customer_2284    Male   56   Indore
# 609    10610  2025-08-14        2223  Customer_2223  Female   45    Delhi
#
#      State Region ProductID     Category Product  Quantity  UnitPrice  \
# ...

# %%
df.set_index("CustomerID", inplace = False)
# Out:
#             OrderID   OrderDate   CustomerName  Gender  Age     City  State  \
# CustomerID
# 2271          10001  2025-12-27  Customer_2271  Female   52  Gwalior     MP
# 2194          10002  2025-08-12  Customer_2194    Male   53   Indore     MP
# 2135          10003  2025-05-08  Customer_2135    Male   27  Lucknow     UP
# 2137          10004  2025-07-18  Customer_2137    Male   27   Indore     MP
# 2071          10005  2025-04-29  Customer_2071    Male   31  Gwalior     MP
# ...             ...         ...            ...     ...  ...      ...    ...
# 2062          10996  2025-08-21  Customer_2062  Female   48    Delhi  Delhi
# 2034          10997  2025-05-21  Customer_2034  Female   40   Mumbai     MH
# 2217          10998  2025-09-12  Customer_2217    Male   32   Indore     MP
# 2220          10999  2025-02-09  Customer_2220  Female   39   Mumbai     MH
# 2058          11000  2025-01-02  Customer_2058    Male   45   Indore     MP
#
# ...

# %%
df.reset_index(drop = True, inplace = False)
# Out:
#      OrderID   OrderDate  CustomerID   CustomerName  Gender  Age     City  \
# 0      10001  2025-12-27        2271  Customer_2271  Female   52  Gwalior
# 1      10002  2025-08-12        2194  Customer_2194    Male   53   Indore
# 2      10003  2025-05-08        2135  Customer_2135    Male   27  Lucknow
# 3      10004  2025-07-18        2137  Customer_2137    Male   27   Indore
# 4      10005  2025-04-29        2071  Customer_2071    Male   31  Gwalior
# ..       ...         ...         ...            ...     ...  ...      ...
# 995    10996  2025-08-21        2062  Customer_2062  Female   48    Delhi
# 996    10997  2025-05-21        2034  Customer_2034  Female   40   Mumbai
# 997    10998  2025-09-12        2217  Customer_2217    Male   32   Indore
# 998    10999  2025-02-09        2220  Customer_2220  Female   39   Mumbai
# 999    11000  2025-01-02        2058  Customer_2058    Male   45   Indore
#
#      State Region ProductID     Category   Product  Quantity  UnitPrice  \
# ...

# %%
df.isnull()
# Out:
#      OrderID  OrderDate  CustomerID  CustomerName  Gender    Age   City  \
# 0      False      False       False         False   False  False  False
# 1      False      False       False         False   False  False  False
# 2      False      False       False         False   False  False  False
# 3      False      False       False         False   False  False  False
# 4      False      False       False         False   False  False  False
# ..       ...        ...         ...           ...     ...    ...    ...
# 995    False      False       False         False   False  False  False
# 996    False      False       False         False   False  False  False
# 997    False      False       False         False   False  False  False
# 998    False      False       False         False   False  False  False
# 999    False      False       False         False   False  False  False
#
#      State  Region  ProductID  Category  Product  Quantity  UnitPrice  \
# ...

# %%
df.isnull().sum()
# Out:
# OrderID         0
# OrderDate       0
# CustomerID      0
# CustomerName    0
# Gender          0
# Age             0
# City            0
# State           0
# Region          0
# ProductID       0
# Category        0
# Product         0
# Quantity        0
# UnitPrice       0
# DiscountPct     0
# Sales           0
# Cost            0
# Profit          0
# PaymentMode     0
# SalesPerson     0
# dtype: int64

# %%
df.dropna(inplace = True)
