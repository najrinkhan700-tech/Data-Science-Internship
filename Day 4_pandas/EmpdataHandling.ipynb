# %%
import pandas as pd

# %%
emp_data = {
    "Name": [
        "Aman", "Riya", "Rahul", "Sneha", "Arjun",
        "Pooja", "Karan", "Neha", "Vikas", "Simran",
        "Ankit", "Priya", "Rohit", "Meena", "Sahil",
        "Kavya", "Deepak", "Nisha", "Yash", "Tina"
    ],

    "Age": [
        24, 26, 28, 25, 30,
        27, 29, 23, 31, 26,
        28, 24, 32, 27, 29,
        25, 33, 26, 30, 24
    ],

    "Salary": [
        25000, 32000, 40000, 28000, 50000,
        35000, 42000, 26000, 55000, 33000,
        41000, 27000, 60000, 36000, 45000,
        30000, 65000, 34000, 48000, 29000
    ],
    "Performance_Score": [
        78, 85, 90, 76, 95,
        88, 82, 74, 96, 80,
        89, 77, 98, 84, 91,
        79, 99, 83, 92, 75
    ]
}

# %%
df = pd.DataFrame(emp_data)

# %%
df
# Out:
#       Name  Age  Salary  Performance_Score
# 0     Aman   24   25000                 78
# 1     Riya   26   32000                 85
# 2    Rahul   28   40000                 90
# 3    Sneha   25   28000                 76
# 4    Arjun   30   50000                 95
# 5    Pooja   27   35000                 88
# 6    Karan   29   42000                 82
# 7     Neha   23   26000                 74
# 8    Vikas   31   55000                 96
# 9   Simran   26   33000                 80
# 10   Ankit   28   41000                 89
# 11   Priya   24   27000                 77
# 12   Rohit   32   60000                 98
# 13   Meena   27   36000                 84
# 14   Sahil   29   45000                 91
# 15   Kavya   25   30000                 79
# 16  Deepak   33   65000                 99
# 17   Nisha   26   34000                 83
# 18    Yash   30   48000                 92
# 19    Tina   24   29000                 75

# %%
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#              Age        Salary  Performance_Score
# count  20.000000     20.000000          20.000000
# mean   27.350000  39050.000000          85.550000
# std     2.870448  11632.418403           7.963568
# min    23.000000  25000.000000          74.000000
# 25%    25.000000  29750.000000          78.750000
# 50%    27.000000  35500.000000          84.500000
# 75%    29.250000  45750.000000          91.250000
# max    33.000000  65000.000000          99.000000

# %%
print("Information All about Employees:")
print(df.info())
# Out:
# Information All about Employees:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               20 non-null     str
#  1   Age                20 non-null     int64
#  2   Salary             20 non-null     int64
#  3   Performance_Score  20 non-null     int64
# dtypes: int64(3), str(1)
# memory usage: 772.0 bytes
# None

# %%
df.shape
# Out:
# (20, 4)

# %%
df.size
# Out:
# 80

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Performance_Score'], dtype='str')

# %%
print(df[["Age","Salary"]])
# Out:
#     Age  Salary
# 0    24   25000
# 1    26   32000
# 2    28   40000
# 3    25   28000
# 4    30   50000
# 5    27   35000
# 6    29   42000
# 7    23   26000
# 8    31   55000
# 9    26   33000
# 10   28   41000
# 11   24   27000
# 12   32   60000
# 13   27   36000
# 14   29   45000
# 15   25   30000
# 16   33   65000
# 17   26   34000
# 18   30   48000
# 19   24   29000

# %%
print(df[df["Salary"] > 50000])
# Out:
#       Name  Age  Salary  Performance_Score
# 8    Vikas   31   55000                 96
# 12   Rohit   32   60000                 98
# 16  Deepak   33   65000                 99

# %%
print(df[(df["Age"] >= 30) & (df["Salary"] > 50000)])
# Out:
#       Name  Age  Salary  Performance_Score
# 8    Vikas   31   55000                 96
# 12   Rohit   32   60000                 98
# 16  Deepak   33   65000                 99
