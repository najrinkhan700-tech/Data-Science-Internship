# %%
import pandas as pd

# %%
pd.read_csv("Cleaned_SalesDataset.csv")
# Out:
#      OrderID   OrderDate CustomerName   Age     City   Product     Category  \
# 0          1  2025-10-20        Aarav  45.0   Jaipur    Laptop  Electronics
# 1          2  2025-03-24       Aarav   51.0   Jaipur  Keyboard  Accessories
# 2          3  2025-03-13       Ayesha  42.0   Jaipur  Keyboard  Accessories
# 3          5  2025-01-03        Kabir  26.0   Mumbai  Keyboard  Accessories
# 4          7  2025-05-03        Aarav  20.0   Jaipur  Keyboard  Accessories
# ..       ...         ...          ...   ...      ...       ...          ...
# 825      994  2025-04-10       Najrin  22.0   Bhopal   Printer       Office
# 826      995  2025-11-26         Zoya  33.0   Jaipur  Keyboard  Accessories
# 827      996  2025-05-18         Riya  39.0   Jaipur    Laptop  Electronics
# 828      998  2025-11-04         Diya  54.0  Chennai    Laptop  Electronics
# 829      999  2025-09-16         Riya  40.0   Mumbai  Keyboard  Accessories
#
# ...

# %% [markdown]
# # Business Insights

# %% [markdown]
# ## Observation 1

# %%
# The Electronics category generated the highest sales among all categories.

# %% [markdown]
# ## Observation 2

# %%
# The North region recorded the highest overall revenue.

# %% [markdown]
# ## Observation 3

# %%
# UPI was the most frequently used payment method.

# %% [markdown]
# ## Observation 4

# %%
# The average sales amount per order was approximately ₹XXXX.

# %% [markdown]
# ## Observation 5

# %%
# There were no duplicate records after data cleaning, resulting in a clean dataset ready for analysis.
